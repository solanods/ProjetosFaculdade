# %% [markdown]
# <a href="https://colab.research.google.com/github/solanods/ProjetosFaculdade/blob/main/NLP_with_Spacy_and_Sklearn_refactor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Identificação**: Solano Cruz Júnior (2919585), Rogério Dourado Felix (2892220), Newton Douglas da Silva Nascimento (2733408), Raimundo de Sousa Lima Filho (2709691)
#
# ---
#
#
#
#
#
# # Tema: Natural Language Processing (NPL) para análise de sentimentos em postagens do Twitter
#
# O uso de inteligência artificial e machine learning para atividades de mineração de textos da web se apresenta como uma riquíssima fonte de insights para a ciência de dados. Nesse contexto, frameworks de aprendizado de máquina como Sklearn, Keras e Tensorflow têm dominado a cena, realizando desde tarefas simples até a criação de autoresponders, bots, classificadores de texto e vários sistemas de diálogo que determinam o significado das frases.
#
# Um framework bastante poderoso e com uma curva de aprendizagem um pouco mais curta em relação aos já citados é a biblioteca Spacy. Escrita em Python, possui suporte para mais de 60 idiomas. De código aberto, foi projetada para construir sistemas de extração de informações ou de compreensão de linguagem natural. Também foi desenvolvida para uso em produção e fornece uma API concisa e fácil de usar.
#
#
# > **Objetivo**
#
# Esse projeto tem como objetivo treinar um modelo capaz de avaliar se uma determinada frase apresenta sentimento POSITIVO ou NEGATIVO.
#
# > **Especificação Técnica**
#
#
# Dataset: Para desenvolvimento desse projeto, será utilizado o dataset
# denominado Train50, disponível em:  https://github.com/solanods/ProjetosFaculdade/blob/main/Train50.csv.
#
#
#
# > **Formato:** A base de dado está em formato CSV. Train 50.csv possui 50mil registros e 5 colunas.
#
# > **Métodos de Pŕe-processamento:** Será criada uma função em Python para a limpeza e pré-processamentos textuais
#
# Letras minúsculas: serão priorizadas no case das strings.<br>
# Nome do usuário: será removido junto do caractere (@)<br>
# URLs: remoção<br>
# Espaços em branco: remoção<br>
# Stop words: remoção<br>
# Lematização: aplicação<br>
# Pontuações: remoção<br>
#
#
#
# > **Tarefa de Aprendizado:**
#
# Serão utilizados métodos e funções do Sklearn a saber:
#
#
#
# TfidfVectorizer: Converte uma coleção de documentos de texto em uma matriz de contagens de token
#
# accuracy_score: calcula a precisão do subconjunto
#
#
# Pipeline:  usado para encadear vários estimadores em um. Isso é útil, pois geralmente há uma sequência fixa de etapas no processamento dos dados, por exemplo, seleção de recursos, normalização e classificação.
#
# LinearSVC: classes capaz de realizar classificação binária e multiclasse em um conjunto de dados.

# %% [markdown]
# IMPORTAÇÃO E INSTALAÇÃO DAS BIBLIOTECAS

# %%
# !pip install -q spacy==2.2.3
# Out:
#      |████████████████████████████████| 10.4 MB 5.1 MB/s
#      |████████████████████████████████| 2.2 MB 46.2 MB/s

# %%
#atualização da biblioteca Spacy para português
# !python3 -m spacy download pt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pt_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.2.5/pt_core_news_sm-2.2.5.tar.gz (21.2 MB)
#      |████████████████████████████████| 21.2 MB 1.2 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from pt_core_news_sm==2.2.5) (2.2.3)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.21.6)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (7.3.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.64.0)
# Building wheels for collected packages: pt-core-news-sm
#   Building wheel for pt-core-news-sm (setup.py) ... done
#   Created wheel for pt-core-news-sm: filename=pt_core_news_sm-2.2.5-py3-none-any.whl size=21186281 sha256=3338c9acae84f2ec549ee25911b03e36c28bd51cadfbcb82c45627d08aa12f64
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5c2gyl24/wheels/c3/f9/0c/5c014a36941a00f5df5fc0756cb961d7c457a978e697a6ce3b
# Successfully built pt-core-news-sm
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/pt_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/pt
# You can now load the model via spacy.load('pt')

# %%
import pandas as pd
import string
import spacy
import re
# Machine learning imports
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
# Divide o dataset em treino e teste
from sklearn.model_selection import train_test_split

# %%
#carregar os dados
df = pd.read_csv('/content/Train50.csv', delimiter=';')

# %%
df.shape
# Out:
# (50000, 5)

# %%
df.head()
# Out:
#                     id                                         tweet_text  \
# 0  1050785521201541121  @Laranjito76 A pessoa certa para isso seria o ...
# 1  1050785431955140608  @behin_d_curtain Para mim, é precisamente o co...
# 2  1050785401248645120  Vou fazer um video hoje... estou pensando em f...
# 3  1050785370982547461  aaaaaaaa amei tanto essas polaroids, nem sei e...
# 4  1050785368902131713  Valoriza o coração do menininho que vc tem. El...
#
#                        tweet_date  sentiment query_used
# 0  Fri Oct 12 16:29:25 +0000 2018          1         :)
# 1  Fri Oct 12 16:29:04 +0000 2018          1         :)
# 2  Fri Oct 12 16:28:56 +0000 2018          1         :)
# 3  Fri Oct 12 16:28:49 +0000 2018          1         :)
# 4  Fri Oct 12 16:28:49 +0000 2018          1         :)

# %%
#base de dados com 5000 registros (tweets)
#sentimento negativo label 0
#sentimento postivo label 1

df['sentiment'].value_counts()
# Out:
# 1    25000
# 0    25000
# Name: sentiment, dtype: int64

# %%
# o conjunto de dados possui duas colunas do tipo inteiro e três colunas do tipo string
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          50000 non-null  int64
#  1   tweet_text  50000 non-null  object
#  2   tweet_date  50000 non-null  object
#  3   sentiment   50000 non-null  int64
#  4   query_used  50000 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 1.9+ MB

# %%
#eliminamos as colunas que não vamos usar
df.drop(['id', 'tweet_date', 'query_used'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                                           tweet_text  sentiment
# 0  @Laranjito76 A pessoa certa para isso seria o ...          1
# 1  @behin_d_curtain Para mim, é precisamente o co...          1
# 2  Vou fazer um video hoje... estou pensando em f...          1
# 3  aaaaaaaa amei tanto essas polaroids, nem sei e...          1
# 4  Valoriza o coração do menininho que vc tem. El...          1

# %%
#confirmar se não há valores nulos no dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  50000 non-null  object
#  1   sentiment   50000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 781.4+ KB

# %% [markdown]
# # Função para pré-processamento dos textos
#
# ## Serão eliminados de cada registro da base de dados
#
# ###Letras maiúsculas
# ###Nome do usuário (@)
# ###URLs
# ###Espaços em branco
# ###Stop words
# ###Lematização
# ###Pontuações

# %%
# carregamento  do objeto spacy em português
nlp = spacy.load('pt')
nlp

# %%
# construir uma lista de stop words a serem filtradas
stop_words = spacy.lang.pt.stop_words.STOP_WORDS

# %% [markdown]
# Stop words (ou palavras de parada – tradução livre) são palavras que podem ser consideradas irrelevantes para o conjunto de resultados a ser exibido em uma busca realizada em uma search engine. Exemplos: as, e, os, de, para, com, sem, foi.

# %%
def preprocessamento(texto):
  # manter tudo em letras minúsculas
  texto = texto.lower()

  # eliminar nome do usuário
  texto = re.sub(r"@[A-Za-z0-9$-_@.&+]+", ' ', texto)

  # eliminar urls
  texto = re.sub(r"https?://[A-Za-z0-9./]+", ' ', texto)

  # eliminar espaços em branco
  texto = re.sub(r" +", ' ', texto)

   # Lematização
  documento = nlp(texto)

  lista = []
  for token in documento:
    lista.append(token.lemma_)
  
  # Usamos uma compressão de lista para eliminar Stop words e pontuações
  lista = [palavra for palavra in lista if palavra not in stop_words and palavra not in string.punctuation]
  lista = ' '.join([str(elemento) for elemento in lista if not elemento.isdigit()])
  
  return lista

# %% [markdown]
# ## AGORA VAMOS APLICAR NOSSA FUNÇÃO NA BASE DE DADOS

# %%
df['tweet_text'] = df['tweet_text'].apply(preprocessamento)
#esta linha de código vai rodar por aproximadamente 10min

# %%
df.head()
# Out:
#                                           tweet_text  sentiment
# 0    o pessoa certo parir seriar o valer e azeved...          1
# 1    parir mim precisamente o contrário :) vir o ...          1
# 2  video hoje ... pensar falar sobrar o meter csg...          1
# 3  aaaaaaaa amar polaroids expressar o quantum to...          1
# 4  valorizar o coração menino vc diferente o sorr...          1

# %%
#localizados valores nulos na coluna tweet text
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  50000 non-null  object
#  1   sentiment   50000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 781.4+ KB

# %%
#eliminar os valores nulos
df = df.dropna()

# %%
#Linear Support Vector Classification.
#toma como entrada dois arrays: um array X de shape contendo as amostras de treinamento e um array de rótulos de classe (strings ou inteiros)
classifier = LinearSVC()

# %% [markdown]
# COMPREENDENDO TF-IDF (TERMO FREQUÊNCIA-FREQUÊNCIA INVERSA DE DOCUMENTO)
#
# TF-IDF significa Frequency Inverse Document Frequency of records. Pode ser definido como o cálculo da relevância de uma palavra em uma série ou corpus para um texto. O significado aumenta proporcionalmente ao número de vezes que uma palavra aparece no texto, mas é compensado pela frequência da palavra no corpus (conjunto de dados).

# %%
#Converte uma coleção de documentos brutos em uma matriz de recursos TF-IDF.
tfvectorizer = TfidfVectorizer()

# %%
# Features and Labels
xlabels = df['tweet_text']
ylabels = df['sentiment']

# %%
#trainning the model
# random state controla o embaralhamento dos dados antes da divisão
X_train, X_test, y_train, y_test = train_test_split(xlabels, ylabels, test_size=0.3, random_state=42)

# %% [markdown]
# PIPELINE
#
# Aplica sequencialmente uma lista de transformações e um estimador final. As etapas intermediárias do pipeline devem ser 'transformações', ou seja, devem implementar fit e transform métodos. O estimador final só precisa implementar fit. O objetivo do pipeline é reunir várias etapas que podem ser validadas de forma cruzada ao definir parâmetros diferentes

# %%
# Create the  pipeline to vectorize and classify 
pipe = Pipeline([('vectorizer', tfvectorizer),
                 ('classifier', classifier)])

# %%
# Fit our data
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()), ('classifier', LinearSVC())])

# %%
# Predicting with a train dataset
sample_prediction = pipe.predict(X_train)

# %%
# Prediction Results
# 1 = Positive review
# 0 = Negative review
for (tweet,pred) in zip(X_train,sample_prediction):
    print(tweet,"Prediction=",pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# parir aturar hoje sortir :) Prediction= 1
# ai manir esperançar :(( dia bostar Prediction= 0
# provir cardiologia pra provar o quantum merda estudar o semana :) Prediction= 1
#   o nao abandonar :) Prediction= 0
# vir garoto hj e pessoalmente o caro d :) Prediction= 0
# ano achar umar foto o site uol deus achar parar achar foto d dia ♥ querer salvar o foto :( rock in rir dia 18/09 Prediction= 0
#   anjo :( Prediction= 0
# ficar triste o pessoal portar e :((( Prediction= 0
#   migar :( Prediction= 0
#   opaa valeuu ❤ ️ 1º flamenguista q :) Prediction= 1
#   conseguir :( Prediction= 0
# pôr o felicidade frente e admirar tar o merda :) Prediction= 1
# tou o sair d casar agr :) Prediction= 1
# seguir :) Prediction= 1
# bar :( deee8dd0-ce0a-413d-a16e-9ab432225f35 Prediction= 0
#   q visitar ficar feliz conhecer oq vc n semana vibe e casar voltar esperar coração falar comigo :) Prediction= 1
# ai angústia :(( Prediction= 0
# precisar conversar o madu :((( Prediction= 0
# ...... o holocausto o assustador estudar o fascismo estarrecedor liar e achar passar acontecer umar erva daninho raiz poderoso deixar crescer pelar amor deus :( Prediction= 0
# o o longo dia onti comer prato :) feliz hj to sofrido Prediction= 1
# jn falar min sobrar lula pt sérgio morar etc bolsonaro filhar puta falir pai medo haddad ganhar medo o bolsonaro ganhar pai manir dor Prediction= 0
#   migar triste difícil paciência gente bêbado evitar brigar :) outro simples shsush Prediction= 1
# contar negócio p luana hj mandar manir vc eh mt troxa eh anjo novidade ai faltar ne :) Prediction= 1
#   anao q pra escola :( Prediction= 0
#   nojento e difícil hj dia cê imaginar :( Prediction= 0
# taehyung~ ano amável adorar umar farra complexo rancoroso e brincalhão melhor amigar namjoon jimin e jungkook pobre taetae :))) £ ¥ Prediction= 1
# querer entrar grupar lovatics :(( Prediction= 0
# tirar umar foto querer pra relembrar semana marcante pra mim to mear bad causar d :( Prediction= 0
#   :( o ciro seriar pelar rejeiçoes e pelar planar governar d ne o pessoa virar n umar alternativo pt e bozo o ruim passar o apoia-lo pq considerar o planar governar d o melhor triste mt difícil Prediction= 0
# ficar aus maravilhoso abandonar e ficar triste merecer :( Prediction= 0
#   dinheiro pra comer to :( Prediction= 0
# o melhor envelhecer e doente perceber realmente contar o melhor sabedoria o suficiente pra mandar gente foder :) Prediction= 1
# tô triste alguém pago o viagem pra grécia :( Prediction= 0
#   d Prediction= 1
#   same here trabalhar preciso pc parir o sushi servir tábua cortar :) Prediction= 1
# abrir o bocar medo morto :( Prediction= 0
# obrigar deixar :) Prediction= 1
# roubar suar moto pelar dia umar carona :) Prediction= 1
# dia irar sorriso tam intenso vc sorrir e sorriso o motivar pra continuar sorrir :( Prediction= 1
# bostar d Prediction= 0
#   achar tapao gt Prediction= 0
# 01/10 dia santo terezinha santo rosar ano passar ganhar lindo rosar azul roxo e amarelo ano poxa tetê :( kkkkk Prediction= 0
# perder o sono e nenhum sedar :( Prediction= 0
#   otaria :( Prediction= 0
#   vir :) Prediction= 0
#   esquecer mim :( Prediction= 0
# pelar o vidar sentir representar politicamente :) Prediction= 1
# caralho o certo parir mim pelar umar :( Prediction= 1
# perceber jeito elogiar eh mto mongol :( Prediction= 0
#   divo :) Prediction= 1
#   beber :( Prediction= 0
#   nado mudo nado nado kkkk :( Prediction= 1
#   ficar puta q relaxante muscular sono :( Prediction= 0
# dor manir :( Prediction= 0
# comer trocar e colocar o manuela d'avila comer viçar ciro :( Prediction= 0
# ae galera vídeo hoje o ar unboxing yakuza hd chegar recentemente casar d Prediction= 1
# tou o curtir outfit hoje :) Prediction= 1
#   oi brunir verificar o equipar retornar :) Prediction= 1
# garganta tá doer :( Prediction= 0
#   mentiraaaaaaaaaaa carinhoso filhote satanás e debochar mim comigo ruim gt Prediction= 0
# medo d :( Prediction= 0
# servetim Prediction= 1
# adiantar o merda o costa lindo parir ti :)) Prediction= 1
#   hmmmm .. design cursar designer parabém lolo :) Prediction= 1
# querer parir o escolaaaa :( Prediction= 0
# precisar urgente ... :p Prediction= 0
#   ficar bravo comigo :(( Prediction= 1
#   acabar outro fotografia formar querer dizer-vos o inscrição parir o artist 's alley abrir interessar :) Prediction= 1
# dia feriar d Prediction= 1
# o verdade ano kkkkkk — chamar p cvs :) Prediction= 1
#   acontecer cmg e to sentir culpar votar n :( Prediction= 0
# o bernardo ta crescer rapido afff filhooooooo :( Prediction= 0
# dia o turno :))) — dia o querer dia silêncio pfvr Prediction= 1
# tô triste n o cami pra encher o início aula .. :( Prediction= 0
#   disse-te facto obviamente querer :) explicar melhor facto Prediction= 1
#   kazu realmente :) assistir Prediction= 1
# o barulhar intenso :( Prediction= 1
# vender oferecer produto o arte conquistar o confiança e o respeitar cliente parabém o vendedor :) gestaoclick erp diadovendedor vendedor vender Prediction= 1
#   merecer desculpar :) Prediction= 0
# vídeo meter som e gemido porn bué alto tou o loja cidadão e alguém abrir d vezar volumar o :) Prediction= 1
# pessoal tower of god :(( Prediction= 0
# alguem mandar cucat :( Prediction= 0
# tava o esquema pra furar o mamilo amanhã rolar :( Prediction= 0
# gato tá doente :( Prediction= 0
#   o impressão o mundo o estereótipo né cascar grosso terra e mt realistar e pragmático acabar parecer emburrar o fundir o signo amor reger vênus querer falar afeto e confiança touro mandar :) Prediction= 1
#   felicidade :) Prediction= 1
# o valhalla festival amigo :) Prediction= 1
# o amigo glockenwise continuar o caminhar d Prediction= 1
# achar real q reprovar filosofia kkkkkk q fase q lixar prof :) Prediction= 1
# infelizmente o sono q derrotar :( o tossir tava chegar o sala e automaticamente ficar cansaço e tossir mto Prediction= 0
# inspiração p escrever q bostar :( Prediction= 0
# achar normal ter-me deixar dormir o e noite e acordar bue toar manhã o mãe o mandar o pai meter bichar o quartar :)) Prediction= 1
#   comer gatar kkkkkkkk entender :p Prediction= 0
# lolita internadissima e o mãe preocupar mundo :( Prediction= 0
#   decepcionar país n conseguir orgulhar brasileiro ... :( Prediction= 0
#   começar o o aula e qm dia ler o constituição comer vc :))) Prediction= 1
#   atar o wpp d chamar parir call :( Prediction= 0
#   euejsijejddj perdoar empolgar :(( Prediction= 0
#   amigo to desesperar real medo :( Prediction= 0
# hoje acordar bué saudade mariano :(( Prediction= 0
#   comer aniversário dia antar comemoração obrigatório :) Prediction= 1
# aula história algum pessoa matar falto :( Prediction= 1
# feliz :)) Prediction= 1
# casar vir :)) Prediction= 1
# eh triste qdo ano nao votar o turno agr segundar turno msm nao q votar obrigatoriamente o papel comer brasileiro e tirar o pt porra :( Prediction= 0
#   algum site algum dica sobrar o legal comentar aprofundar :) Prediction= 1
# o hr passar n hospital ave n guento maisss :( Prediction= 0
#   lindo falar :) Prediction= 1
#   curso o conseguir inscrever sesc :( achar q parar seguir pra parar passar vontade Prediction= 0
# quantum duro :) Prediction= 1
# bar :-( 127e8ded-4a60-4302-8b8f-d7e98a7112da Prediction= 0
#   uahsuahs gostar :p Prediction= 1
#   glóriaaaaaa :) Prediction= 1
# bolso= crente bancada armamentista interesse grileiros haddad= lula gleisi ze dirceu e o populismoo :( Prediction= 0
# dia :-) Prediction= 1
#   concordar tá mear alterar o canal fansubs legendar umar série lbc legendar outro idioma ótimo o outro série d o gente preciso fansub :p Prediction= 1
#   querer bolacha :( Prediction= 0
#   o sábado ... parir :) Prediction= 1
#   achar valer cidadania duplo :( Prediction= 1
# moço hachimitsu q chamar moço querer perdoar o foder q o caro pedir desculpar fdp e super simpatico :((( Prediction= 0
#   ta intolerante serj :( Prediction= 0
#   n perdoar :) Prediction= 0
#   caganeira redar record tv o cabo canal ta pra voce :) Prediction= 1
# opar bbs olhar arrastar pra praia e conseguir postar o inktober11 :) falto criatividade n gostar o cruel Prediction= 1
# o mundo e ti nado :) Prediction= 1
#   :(( amigo feliz mim o gente encontrar encher mimo Prediction= 0
#   o quase o família apoiar :( literalmente o Prediction= 0
#   tirar o siso umar :( e o anestesiar vc anestesiar o céu bocar pq sofrer c Prediction= 0
#   hola you can read it here thread by o frustrante o inevitabilidade to falar vitória derrotar fascista o u … enjoy :) 🤖 Prediction= 1
# amar o nanar :( Prediction= 0
# ai coraçaozinho :( Prediction= 0
# semana mãe viajar e querer ficar :( Prediction= 0
# eiii oq acontecer qnd bty chegar o m vc projetos — simmm anjo o proximo miss you :) Prediction= 1
# bora tomar umar — aaaaa horar to estudar ces chamar :(( Prediction= 1
# amar gente dia and counting :) Prediction= 1
# amar :( tô postar foto zoar pq o vidar d armyselcaday bts Prediction= 0
# ano o pai natal entregar o prender cambridge :)) Prediction= 1
# aahhhhhh grado o asar sunny d Prediction= 1
# ngm cmg af gt Prediction= 0
# acc avail dm agir biar fastresp :) Prediction= 1
#   simmm :( interagir formar superficial umar pessoa msm cabeça coisada d ctg Prediction= 0
#   tardar nao notificar demorar parir responder nao notificar :-( Prediction= 0
# tá apaixonar semana — recíproco adiantar falar :( Prediction= 1
# followfriday parir querido seguidor :) ifttt Prediction= 1
#   misericórdia tô assustar o ódio o pessoa esconder ... sentir livre pra praticar Prediction= 0
#   foder eh ambientar tóxico pra caralho caro :( solidarizar mto c suar situação Prediction= 0
#   babeee esperar ficar melhor okay gt gostar ugh Prediction= 0
# o den nenê :( Prediction= 0
# dia inscreve-te esperar :) Prediction= 1
# gente o desenhar irmão :((( ficar felizinho ensinar o pintar e o escolher o corar aaaa Prediction= 0
# tava pensar umar memphis sg modelar gostar timbrar e aspecto visual :p encaixar o vontade tirar e tá preço mediano claramente umar guitarra boooa dever melhor o achar válido Prediction= 1
#   :( Prediction= 1
# queronotvz arear sandy e luca limar :) Prediction= 1
# realmente nao peno :( Prediction= 0
#   calmo umar conversar :) Prediction= 1
# dormir tardar ficar terminar upar e umar equipar world boss e war front boe to super empolgar o druid :) o nick deixar decidir e ignorar o roupa coitar Prediction= 1
#   aaa fofo :)) contar Prediction= 0
#   ai migar duvidar acontecer :( achar dividir d+ o e cair td o costa rick 🤧 Prediction= 0
# cheio sono :( Prediction= 0
#   entao estudar história :) pt responsável pelar esquema comprar voto história brasil ... defender o democracia o democracia nicaragua cubar Prediction= 1
# querer o amor ladinho s2 :( Prediction= 0
#   guaraná :) Prediction= 1
# o voto hj parir o pcas o categoria agr amanhã :) Prediction= 1
# bebé :((( Prediction= 0
# o o vão-se recompor ... :) Prediction= 1
# comecar o ceto amanhar e esperar resultar rapido q lidar o frutar casar :( Prediction= 0
# iti bebé :) Prediction= 0
#   vergonha foder massss querer q o podcast ajudar :)) Prediction= 1
#   opar obrigar :) Prediction= 1
# querer doce :( Prediction= 0
#   comer :( Prediction= 1
# amor chegar escola :( Prediction= 0
#   acusar admitir :( Prediction= 1
#   d Prediction= 1
# sentir umar país feliz nó o nordestino e ligar :) Prediction= 1
#   ficar triste o o ler umar d :( preciso preocupar perfazer amor o gente amo pelar incluir o defeito Prediction= 0
#   amor ... conversar :( Prediction= 0
#   nao 10k canal organizadinho d Prediction= 1
# ano — :p Prediction= 1
# oh o chamar “ guk ” lembra-me o jeon céu enciumar o o menino conversar achar demorar ... — oh compreender e ficar :) Prediction= 1
#   vir :( Prediction= 0
# answer sair brasília e her tá o staff caraca :( Prediction= 0
#   insistir n converso 2º turno haver fraldar 2º turno converso parir o informar perceber o manipulação o olho e o apoiar espontâneo coação artista o candidatar líder :) Prediction= 1
# acabar gente :( pra conseguir acompanhar o episódio reprisados o 01h44 d madrugar trocadeestilos Prediction= 0
#   o e certo continuar :) Prediction= 1
#   uhum achar q entender tweet :) Prediction= 1
#   olá o email lfreitas mandar currículo e portifólio :) obrigar Prediction= 1
# to triste :( ficatemer Prediction= 0
#   lamentável :( Prediction= 0
# e perder o :( Prediction= 0
#   querer continuar :( Prediction= 0
# segurar o chorar o aula comentario homofobico o grupar familia :) o vidar eh incrivel Prediction= 0
# feliz dia criança pra suar atitude dia :) Prediction= 1
# ⚡ bonito amizade :) Prediction= 1
#   plenamente acordar dia :) Prediction= 1
#   perguntar :( Prediction= 1
# jurar querer gostar gostar mim :( Prediction= 0
#   o óculo ficar :) Prediction= 0
# compensação ficar auxiliar umar cirurgia :) Prediction= 1
# pra jogar dragon quest xi o voz japonês :( o voz gemma nervoso inglês descobrir aguentar sotaque britânico Prediction= 0
# nado melhor alguém conhecer o haddad estudar e mestre psiquiatro forense escutar :( né votar o o bolsonaro imaginar Prediction= 0
# gente tô semi bêbado :) Prediction= 1
#   ai ta impossível :( voce sz Prediction= 0
# assustador :( Prediction= 0
# sala isolar o pessoal tá rir e achar bacana o caro votar o cabina eleitoral umar armar :) Prediction= 1
# querer presentar nené d bichar :) Prediction= 0
# hoje acordar carente mundo querer abraçar sincero f1 trocar idéia :( odiar feirar Prediction= 0
#   luca o entrar contato pra ajudar n ok :) Prediction= 1
# sentir saudade vcs piticas :( vcs junto oq amar o único q sorrir n horar lt;3 Prediction= 0
#   lacrar amigo chamar o harry henry rei humor pisar o hstans :( Prediction= 0
# noite parir ficar o t atar amanhã :) Prediction= 1
#   nao painho comprar cartao amigar :(( Prediction= 0
#   ai anjo ficar :( vc descartável Prediction= 0
#   o funcionar :( Prediction= 0
#   querer :( Prediction= 0
# pessoal umar trégua o político ... pelar sair o pesquisar pfv :) Prediction= 1
# foo :-) ade66e5a-b7ba-4ab6-92e5-351d778aa701 Prediction= 1
# pulseira aço inoxidável :-) Prediction= 1
#   ah manir entrar pt e bozo eh bozo vezar mt triste infelizmente eh o opção :( Prediction= 0
#   oi amar :( Prediction= 1
# seguir estrenando cam d Prediction= 1
#   boooooooooooooom diaaaaaaaa boaaaaaa tardeeeeeeeeeeeeee :-) Prediction= 1
#   amar idade campanha caro kkkkk e vc :) Prediction= 1
#   es mau :(( Prediction= 0
#   aaaaaaa desculpar o gente anna :( Prediction= 0
# o amor negar tá vir dobrar :) Prediction= 0
# hoje terminar o season feartwd e sofrer abstinência assistir o o episódio :((( Prediction= 0
# alguém user pra mim :( Prediction= 0
# gnt umar roda amigo e mt converso jogar :) Prediction= 1
# ai vir o daily o celular ramo bater saudade retirar :( Prediction= 0
#   amigo assistir my pace gostar cavar paciência livrar :) Prediction= 1
#   o spam gt rubiuuuuh eligemeeee 😏 Prediction= 0
# esperançar :( Prediction= 0
#   safadinha e fofynha tá magro pq comido pra viver pelar ruir achar levar ração pra querer trazer pra mim gt Prediction= 0
#   tô sentar :( Prediction= 0
# apreciar :(( Prediction= 0
#   old d reconhecer o Prediction= 1
# desistir brasil ... :( Prediction= 0
# suco laranjo :p Prediction= 1
#   miguelzinhoo :( Prediction= 0
#   simm pqp hoje acordar cansado :( Prediction= 0
#   agr :((( Prediction= 1
# amor ta lindar :-( Prediction= 0
#   :( o gnt mandar msg pra umar primo d e responder né Prediction= 1
#   acreditar n Prediction= 0
#   :( Prediction= 1
# d o semana meter o aparelhar :) Prediction= 1
# querer o blusa consequences :( Prediction= 0
#   :-( querer sumir Prediction= 0
# o maquillalia o o ano deixar enviar o cena cobrança tou mt triste :(( Prediction= 0
# parabém mxxxxx perder o ônibus nao acreditar q vc ta cmg q ajudar :( Prediction= 0
# bomm dia :))) aula hj Prediction= 1
#   feito pego o década elite café paulo o comedir década procurar conhecer alto e nome :) Prediction= 1
# burro e idiota :) Prediction= 1
# bue saudade pessoal vir hojee nao vir o genteeee :((( Prediction= 0
# umar incrível d Prediction= 1
#   :( e processar o pagamento entrar o opção o aparecer bradescard next visar umar fechar o paginar abrir e mudar o opção nenhum bradescard visar normal :( Prediction= 0
#   o ideia bozo e preconceito atingir negativamente mulher negro índio e lgbt encaixar nenhum grupar o mínimo empatia e eleger fascista :) Prediction= 1
# hoje e praia :( Prediction= 1
# adios johnny :) Prediction= 1
#   olá camila auxiliar vir o dm e contar o acontecer esperar :) Prediction= 1
#   foder :(( Prediction= 0
#   umar treta pra coleção :) Prediction= 1
#   otimista migar repente cair meteoro e o gente ficar livrar estupidez d Prediction= 1
# nct so orgulhar deus comer amar beber :( Prediction= 0
#   amar :( precisar desabafar oq coragem fe falar pra Prediction= 0
#   idem :( q ta aparecer notificação twitters srry Prediction= 0
# dia amar neno :( Prediction= 0
# dia pra qm fds dahora d Prediction= 1
# gente o bonoro eleito :( Prediction= 0
#   abandonar nois n poxa :( kkkkkkk Prediction= 0
#   :( Prediction= 1
#   ensinar o arte :) Prediction= 0
# querer chocolate :( auhshuah ganhar comer Prediction= 0
#   nado k parabém pelar história simba :) Prediction= 1
# dormir ninguém converso comigo :( Prediction= 1
# o garganta melhorar :( Prediction= 1
#   q vc interpretar errar b :) Prediction= 1
#   umar historiar contar mts nao acreditar :) Prediction= 1
# gotta love comer o esquerdo juntar candidatar tá mundo ocupar o dedo e o culpar outro pra :))) comer gente querer comer o cu né galera Prediction= 1
#   falar gi meter o bocar pq tardar falar abertamente causar gente burro :p Prediction= 1
# amar receber :( Prediction= 0
#   tô mtt apaixonar aff querer cachorro voltar :( o futurar igual o ti Prediction= 0
#   o tá feio ... correr o bichar pego ficar o bichar comer :( Prediction= 0
# pronto pra desmaiar ansiedade apresentar seminário Prediction= 1
# querer tocar violão :( Prediction= 0
# umar amanhã :( Prediction= 1
#   amar krl pfvr pra conversar :( to livrar vc Prediction= 0
# dscp acompanhar vcs :( prometer acompanhar :( amar vcs 💕 :( Prediction= 0
# enrolar enrolar enrolar so perder min aula filosofi :( Prediction= 0
# to umar dor o corpo parecer nao passar manir :( Prediction= 0
# gritar o trovão vir pra anunciar o chegar tempestade o representar suar canção dia estranhar seguir o lutar o esperançar abalar :( Prediction= 0
# yakisoba :( Prediction= 0
# esperar ficar abrir mão amor imaginar amizade :) Prediction= 0
# sdd blog :( Prediction= 1
# umdiaeuaindavou parar burrice :) Prediction= 1
#   o pequeno ana cair balançar cortar o braço d toc toc o pequeno ana :) Prediction= 1
# gente tô nado :( Prediction= 0
# ficar acalmar botar vídeo louise hay :-) tontissima e pronto pra dormir tomar morrer Prediction= 1
#   o atual conjuntura votar nulo :( n conseguir votar pt Prediction= 0
# precisar abraçar anitta antar ditadura :( Prediction= 0
#   … semana z festival poer :) vir o atrações d show pop \o/ Prediction= 1
# querer caraguejinho :( namjoonamacaranguejinho Prediction= 0
# latada coimbra semana d mamar Prediction= 1
#   o vinil achar tb mano pelar bkstg o cd amigar q umar irmão morar o japão arrumar e tals vender pelar loja o ig encartar e né o japão vinil :( Prediction= 0
#   falar nanar .. saudade safar :p nanar Prediction= 0
#   vc precioso tô triste :( Prediction= 0
# quebrar o julgamento atitude ... o kay o associação deficiente físico divulgar o trabalhar d diferençar né :) Prediction= 1
#   amorr olhar :( Prediction= 0
# e q n o oportunidade :) Prediction= 1
# ai físico :( Prediction= 0
# alguém ensinar comer manter o amizade votar o bozo tá difícil :( Prediction= 0
# acabar o tb e tv :) Prediction= 0
#   🌻 super alegrar 💛 6/10 🍯 peno sair turma :( achar melhorar pessoa parar escola dúvida umar personalidade único continuar o doce saudade gostar ti 😊 Prediction= 0
# tô apaixonar pelar pack :( Prediction= 0
# nd pra fzr perguntar :)) Prediction= 1
#   tomar mano o aguardar informação sobrar :( Prediction= 1
#   fer ficar triste :( natal coletivo o ccxp Prediction= 0
# idear homónimo enganir o endereçar mail e mandar parir o o gmail … bilhete comboiar lausanne parir freiburg haver reservar avião hotel … dia d aproveito-as :-) Prediction= 1
#   chato :( Prediction= 0
# amar muitãoooo :( Prediction= 0
#   pra mim claro d Prediction= 1
#   mentiroso o atar :) Prediction= 1
# manir e tô semana provar to fudendo o provar pq ficar o maratona estudar :) Prediction= 0
#   n falir :( Prediction= 0
# vc cuidar mundo doente tbm :( Prediction= 0
# odiar dormir nado e deixar o o vacuo querer affff :( Prediction= 0
# alguém umar senha pra franz ferdinand o mada pelar amor deus :( Prediction= 0
# to mt triste sério :( Prediction= 0
#   :( amar o comedir incapaz d pq vir estuprar realmente amar Prediction= 0
# causar d chuva n o neném Prediction= 0
#   o caro presidente granitar group acadêmico algum livro publicar o fodona tá certo :) Prediction= 1
# mostrar interessar e mandar msg migos :) Prediction= 1
#   o provavelmente irar conseguir amanhã :)) Prediction= 1
# larissamanoela mpn2018 andar cansar e desanimar :( Prediction= 0
#   posto video ex jornalista demitir plágio :) Prediction= 1
#   pq ta magoar cmg :( Prediction= 0
# mandar “ amar ” e receber :) Prediction= 0
# inktober2018 inktober :p sla pq caneta tá acabar frozen Prediction= 1
# curtir molhar ti o ficar super girar t parir :) Prediction= 1
#   chamar suave :) Prediction= 1
#   achar anjo desculpar :( Prediction= 0
# o beber :((( Prediction= 0
#   triste :((( Prediction= 0
#   same hj n beijo nado :( Prediction= 0
#   infelizmente :( outro dia outro infernar lançar dormir gege :( Prediction= 0
#   vc desenhar melhor q q umar linha :) Prediction= 1
#   informar dever parar escrever merda o internet dia :) Prediction= 1
# noite e nervoso q espetar estourar o cabeça irmão ajudar o meter o lixar o sacar :) Prediction= 1
# aaaaaa tô desesperar eleição deus sofrer e comunidade lgbt imaginar comer devir :( Prediction= 0
#   conseguir :( Prediction= 0
# hoje acordar mear dever melhorar amanhar o lançamento podcast e feliz :) Prediction= 1
#   perceber excluir ficar o abraçar :) Prediction= 0
# hoje dia internacional reclamar mim e entender pq hoje parecer o dia propricio o frente :( Prediction= 0
#   o brasil merecer esperar dia o senado decepção paulo :( Prediction= 0
#   mutcho biene acabar terminar umar penquinha trabalho :) Prediction= 1
#   vontade canto pequeno chegar :)) Prediction= 1
# bar :-( e7c9fdb7-efa6-44b1-a751-730a2a157a42 Prediction= 0
# vir novidade alguém conhecer :) umar dica o bahia salvador musicapopularbrasileira musicar music musik Prediction= 1
#   sksksksksk :)) Prediction= 1
# pros rolar fácil kkkkkkkk querer desbloquear o mãe o vó e o tio status pra o :) Prediction= 1
# esconder mundo :( Prediction= 0
#   chamar e querer comigo :((( Prediction= 0
# mandar o instar :) Prediction= 1
#   superar o sair peyton e luca o temporada one tree hill :( Prediction= 0
#   tadinho sol real friends :( Prediction= 0
#   o rir :( Prediction= 1
#   tmb :) Prediction= 0
#   socar o caro e vc acordar pra realidade :)) Prediction= 1
# bué carente hoje :(( Prediction= 0
#   interessar :) Prediction= 1
# sabrina dormir achar :( Prediction= 0
#   oi :( Prediction= 1
#   o problem po :) pushawardskiervifamcakes Prediction= 1
#   to achar q n conseguir ano q vir n :( Prediction= 0
#   vir falar cmg :( Prediction= 0
# começar o achar espinhar dever o o estresse e o ansiedade semana :( Prediction= 0
#   tao bruto comer hoje basto ler o planar governar pt e comparar o madurar exatamente o :) ano o governar f c o pai e o pessoa achar o pt salvar hahaha prefeito o brasil Prediction= 1
#   umar peno conseguir esperar apoiar o equipar técnico zema rolo spoiller participar :-) Prediction= 1
# tô c dor o ouvir :( Prediction= 0
#   to aprender o básico :) agulhar normal o retas pontar tricar e Prediction= 1
#   ai amg querer :( Prediction= 0
# gostar marino caro tadinha eleição eleger e ngm ligar pra caro :( vao tomar o cu o marino proposto pq pacifista e calmo o pessoa chamar “ fraco ” ai pfvr ne voces o proposto d Prediction= 0
#   incrível valtinho jamais pensar :( Prediction= 0
#   esperar começar o estágio o bagulho ficar louco oheroaihfoiashf o comedir aula arrastar achar o semestre umar disciplinar realmente gostar e sentir psicologia estudar ne :( Prediction= 0
# esquecer :( Prediction= 0
#   o haver :( Prediction= 1
#   ganhar o dia vezar e o fioreze amigão :) Prediction= 1
# parir o cabeleireiro entender pedir parir cortar o pontar o pontar e 9/10 cabelar :) obg Prediction= 1
# acertar documentação filiar o o psol :) Prediction= 1
#   atar pq nao governar parir mulher governar parir o brasileiro o total continuar separatista o decálogo lenin ta seguir o riscar vcs :) Prediction= 1
#   tbm gostar umar sapato namo :( Prediction= 0
#   thanks to luis inácio :) Prediction= 1
#   e comer n pedir :p Prediction= 1
#   positivar :) Prediction= 1
#   morar outro prints caro :( e fake deletado o rede social Prediction= 1
#   grazas :-) Prediction= 1
#   ah :( o mão Prediction= 0
#   querer o rosa :( Prediction= 0
# gcf in saipan jimin misericórdia amar neném :(( Prediction= 0
#   okay obrigar :) Prediction= 1
#   :( tô morrer saudade esperar o gente conseguir amanhã :( Prediction= 0
#   achar o discursar d falar d querer defender o jovem e apoiar mundo o falir detalhar o irmão d namorar umar menino :) e o filho d negro :) Prediction= 1
# olhar deliciar receber mensagem bolsominion feirar chuvoso e triste facistas passar d atingir graduação pó graduação e mestrado família amigo e gente o o redor excelente dia pra tbm :) Prediction= 1
#   ficar :) Prediction= 0
# :( caro estragar foto perfil Prediction= 0
#   acabar d Prediction= 0
# o tirar o chave casar mochila o bolsar frasco perfumar e adivinhar cair e partiu-se :) Prediction= 1
#   parir merecer n mundinho s vezar desmoronar pra gente fase ruim necessário parir dia melhorar vir :) Prediction= 1
# :) riomar recife Prediction= 1
#   caramba ótimo haver ideia diferente dúvida o problema crescer juntar o desrespeitar o minoria prático o xenofobia absurdo o nordeste rolo ano :( Prediction= 1
#   dever difícil kkkk ... :( Prediction= 0
# wpp servir enfeitar :) Prediction= 1
#   redar social anjo julia fingir mim o vzs pessoalmente achar desencantar troste :( Prediction= 0
#   :) critério o voto parir o congresso presidente Prediction= 1
#   manir mancar :( Prediction= 0
# 🧜 🏼‍ ♀ ️ ainnn lindo muitoofeliz termo o aproximar 💛 💛 💛 parceria pra tudoo :)) Prediction= 1
#   esquecer marconi :) Prediction= 1
#   claro e dever mídia imparcial comer jornalista militar real chance ganhar o turno e valer pra manter comer afinal o brasil ótimo :) Prediction= 1
# crer tô sono obrigar mãe :(( agr bora tomar café manhã e torcer pra sono Prediction= 0
#   o corretor :( Prediction= 0
#   ai postar achar horrível :( Prediction= 0
# stalkear perigoso evitar o :) vlw flw Prediction= 1
# autocarro perdido chegar horar atrasar o o treinar :) Prediction= 1
# saudade :( Prediction= 0
#   olhar vc assistir algum dia so dia umar paciência kkkkkkk ficar melhor jurar verdade gente falir morrer n acompanhar o seriar :( esperar n cair Prediction= 1
#   querer brasil real :( Prediction= 0
# querer :( Prediction= 0
# dia :) Prediction= 1
#   porcão bunda velho kkk o perfil e suar foto capar pelar depressão engraçar umar pessoa querer o depressão comentário menosprezar o hahaha :) Prediction= 1
#   ajudar vir e necessário :) Prediction= 1
#   nado :( Prediction= 1
# papel democrático e conversar eleitor b. pra entender o motivo votar e explicar votar democrático d véi explicar querer desenhar Prediction= 1
# importar ganhar perder eleição nó perder comer sociedade :( Prediction= 0
# normalmente o horar voltar pra casar o horar voltar pra escola :) Prediction= 1
# comprar n compromisso o dinheiro q :( Prediction= 0
#   pavilhão andar girar :p Prediction= 1
# naokkkkkkkk :( Prediction= 0
# umar limpo maravilhoso pessoa famosinhas o internet o ig conseguir vencer o stories :) Prediction= 1
# dia dono melhor hoje incrível q amanhã ... q melhor :) Prediction= 1
#   seguiii :))) Prediction= 1
# tristeza :( Prediction= 0
#   esperar passar e ficar melhor :) Prediction= 1
#   ficar chocar o ciro pra segundar turno vir gente falar votar n :( Prediction= 0
# o gente icon preto o tl :( Prediction= 0
# tnh começar o tecido parir o vestir pq q deixar parir horar e dps acabar calçar ganga :) Prediction= 1
#   aproveitar :) Prediction= 1
#   umar :-) Prediction= 1
# ba tava tri feliz o solasso q tava Prediction= 0
# anjo vidar :( Prediction= 0
#   precisar ajudar pra conhecer grupar ... :) Prediction= 1
#   confiar d Prediction= 1
#   o :( Prediction= 1
#   casar pessoa pelar igreja :) preferir cuspir copo curiosidade livrar andar Prediction= 1
#   tbm amar :( Prediction= 0
# mudança horário escritório agr ficar o livre passar o tardar casar legar algum amigar querer companhia ... :) Prediction= 1
# pelar o stora geo faltar e secalhar sair o 16:50 :) Prediction= 1
# precisar umar rinoplastia o nariz afeta auto estimar e deixar triste pagar pra mim :( Prediction= 0
# tô lixar amigo ideia o aus d :( Prediction= 0
# mãe votar o bolsonaro :( Prediction= 1
# vontade realizar :) Prediction= 1
#   pensar q querer vc o af :( Prediction= 0
#   olho e verde e bocar carnudo d tirar sério umar peno umar xexelenta depilar o axila :p Prediction= 1
#   achar cliente ... o retornar folclore brasileiro show o e postar o publicação valer :) Prediction= 1
#   :( tá foder godinho Prediction= 0
#   querer to aceitar hihi :) Prediction= 1
# tweet sincero o coração entristecer o dia vir e escutar absurdo ... e parir o saudar mental e paz preferir silenciar e rezar q o deus q governar e o conduzir vdd :) Prediction= 1
#   preferir ficar cm vc :) Prediction= 1
# aaaaaaaaa :( Prediction= 0
#   graça o deus :(( Prediction= 0
#   negativar caber parir o candidato :) votar o pt n significar q ladrão corrupto Prediction= 1
#   aaaaaa :( o vidar umar bostar Prediction= 0
# pesquisar mostrar anime vc recomendar o pessoa assistir porq gostar horrivel d Prediction= 1
# aniversário pai e chatear umar camisa fluminense pra :( Prediction= 0
# amanhã(09/10 s 18h o salão poente centenário engenhar encontrar ofchila o apresentação graduar e pesquisador magnus kenji projeto sic sobrar o impacto ruptura sino-soviética o indochina contar o suar presença :) Prediction= 1
# importante realmente melhorar o dia deus amar vc eh incrível anjo — ficar feliz melhorar o dia importante :p Prediction= 1
#   pedir :) Prediction= 1
#   exatamente e umar desculpinha parir e o provavelmente caro sair impune d Prediction= 1
#   :( silenciar algum Prediction= 1
# dólar subir :( r$ 3,74 s 09:50 Prediction= 1
#   bolsar família nao comprar passagem parir país armamentista direito ... amigo o canadá o armar :) Prediction= 1
#   dia loren :) Prediction= 1
#   parabém hermano d Prediction= 1
#   atar melhor :) ahasara Prediction= 1
#   qnd comer mamão colocar aveia tb fibra ajudar beber água certo o casar :))) Prediction= 1
# querer cabelão início ano :( Prediction= 0
#   deus anjo :( ♥ Prediction= 0
# conseguir esquecer-me e-mail meter e o contar bloquear o :) Prediction= 1
# pensar ruim passar o dia :) Prediction= 0
#   dia absurdo colocar opinião e avisar iriar tolerar interpelar o pessoa achar direito d :( Prediction= 0
#   ah kajdksjsk criatividade funcionar tratar faltar aula contooo :) Prediction= 1
# rosar hoje :) Prediction= 1
# o caro responder msg o whatsapp desejar parabém pra parabém gatão ♥ ️ ♥ ️ merendar sexo e vídeo gamar o suar vidar :) Prediction= 1
#   lindinho o livro :) Prediction= 1
# e exatamente n o vrdd umar q aparecer olhar o lágrima :p Prediction= 0
# gostar tradução :) Prediction= 1
# outubro o ficar triste assinante tv o cabo space filme terror horar magia :( Prediction= 0
# umar viagem :) Prediction= 1
#   o verdade o mundo o cabeça gente comer :) Prediction= 0
# foo :) 3b2e1d6a-a6dd-471f-96e7-e78696a27811 Prediction= 1
#   olhar fofo conhecer o milhão ano e ya :) Prediction= 1
# to cheirosinha pra ninguém fungar o pescoço :( Prediction= 0
# acordar mensagem foto mau e o feirar prometer merecer :(( Prediction= 0
# cheiro decepção kkkkk :( Prediction= 0
# o entender caro pra show o brasil ... vcs n noção .. pedir pra divulgar o bts e o produto d vir pro br pq algum marcar interessar e patrocinar show d :) Prediction= 1
#   concordar ficar indignar pq o formar mudar quadrar vitinho conformar o máscara q o pt colocar o dificuldade o o invés achar outro modo mudá-las triste pq o nordeste mt o visão o outro d n p insistir o errar :( Prediction= 0
#   vc ganhar cascudo o suar cabeça d Prediction= 1
# o cabelo :((( Prediction= 0
# índio ganhar lembrar o mãe hahaha achar bonito o olho e o cor pelar :) Prediction= 1
#   alguém pfvr narrar o diálogo p ouvir o “ ” e o o relacionar ... to fone :( Prediction= 0
# começar o estudar psicologia :))) Prediction= 1
#   arrumar :) Prediction= 1
# caralho q separar amigo aaaaaaa mundo faculdade juntar morar juntar e o msm quartar :( Prediction= 0
# dia pra realmente o começar olhar ... parabém o o envolvido :) Prediction= 1
#   lumaaaaaaaaaaaaa relaaaaaaaaaxaaaaaaaaaaaaaaa parecer agr ficar :) bolsar haddad ganhar o mudança q sentir o economia Prediction= 1
# so grudar comigo :( Prediction= 0
#   o falhar comer fa :( Prediction= 0
#   razão nado vir :) foder e Prediction= 1
#   triste :( deus ajudar Prediction= 0
# umar amor e ódio fito neoprene coçar forçar ajudar :( Prediction= 0
# o gente o parir cagar ti e o apartir :) Prediction= 1
#   o joão dório tá governador o vexame tá ficar :p Prediction= 1
# odiar adoecer propor o perfeccionista e o esforçar pra atender padrão qualidade hoje entregar negociar bocar pq passar o domingo febre e conseguir trabalhar :( Prediction= 1
# parabens pra mim :( Prediction= 1
#   irrelevant :) -sara Prediction= 1
# foo :-) 1b207bb0-e82a-4d86-af1e-9b857295c250 Prediction= 1
#   hm tá :( Prediction= 0
# acordar hoje detetive e descobrir o procurar quase desistir e esperar encontrar :))) Prediction= 1
#   motivo parir :( contar o o super junior melhorar dia mv umar olhar Prediction= 1
# ano perder umar pessoa amar :( Prediction= 0
#   tb :( Prediction= 0
# o guerreiro ... ano atreves-te o mostrar o forçar haver ti inscreve-te ;) vídeo foto video stop :) Prediction= 1
# shookt sa gradar sa rj :)) Prediction= 1
# umar semana dia umar oportunidade d Prediction= 1
#   amor ❤ obrigar verdade umar peno gente apoiar fascista nojento falto empatia :( Prediction= 0
#   see you sa lez dis :) Prediction= 1
#   aaaa tou o ganhar coragem mor :( Prediction= 0
#   esperar tocar o o 20$ o fortnite skins o código pavos o pase batalla :( Prediction= 0
#   entender oq vc tá sentir umar angústia umar incerteza umar vontade desistir né o baque forte cair lutar achar q vc sentir comer sentir tbm q parecer inútil convencer o anti-pt q o bonoro né :( Prediction= 0
#   noto jeito nenhum :( trocadeestilos Prediction= 0
# odiar o pt faculdade pessoa minoria fantástico merecer sofrer represália o ruir gay negro pleno sec :) Prediction= 1
# dia feriar taubaté :) trabalhar jacareí :( Prediction= 1
# idai merda pelar brincar dog amanhar :p Prediction= 1
#   bravo Prediction= 1
# n gostar triste o t — gostar ficar triste kkkkk :( Prediction= 0
#   algum dia semana voltar pra casar :( Prediction= 1
# pack combinar foda-se :) Prediction= 1
# o saudade tá matar — aaa vir pra e vir :( Prediction= 0
#   referir discordar tai humano depender fofoca — errar outro Prediction= 1
# ai gente tadinho ta triste verdade :( n aguentar seriar Prediction= 0
#   putaquepariu :( Prediction= 0
#   alguem morrer :) Prediction= 0
# querer filmar e o vontade :) Prediction= 0
#   seleção natural pq n situação chance morrer apoiar kkkkk :( rir nervoso Prediction= 0
# o irmão votar o haddad o turno e cair fake news o whatsapp e tá pensar votar o bolsonaro :) Prediction= 1
#   exato vir o comentário foto acreditar conseguir chegar o pontar :( Prediction= 0
#   melhor facista :( Prediction= 1
#   esculhamba :( buá buá buá buá Prediction= 0
# linux Prediction= 1
# amanhã o dia vencer :) Prediction= 1
#   o unhar d e machucar extremamente frágil :((( Prediction= 0
# chorar pq vir video caro bater cabra tpm is going :( Prediction= 0
#   hay quemá to'a xuxa gt Prediction= 0
# o melhor parir esconder cabelar :( Prediction= 1
# beber claro :))) Prediction= 1
# tre meter o rabo d :) Prediction= 1
#   saudade senhor comandar o fundir quadrar :) Prediction= 1
#   ws si :((( Prediction= 0
#   e o precisar ti :(( Prediction= 1
# algum caralha motivar to surdir :) Prediction= 1
#   tbm amar vc :) Prediction= 0
#   vc desenho bonito o vidar :p Prediction= 1
# querer acordar amanhã ap o beirar mar :( Prediction= 0
# foo :) 5cc501dc-112e-44e1-bd7d-8a3b59e6c50e Prediction= 1
#   to brincar né :) Prediction= 0
# ninguém :( Prediction= 0
# triste acabar grey ’s :( Prediction= 0
#   esperar :) Prediction= 1
# mg apaixonar ti lindo e querer mim amar aproximar ano e sentir sdd ano q vir :( Prediction= 0
# sairam o estudar mostrar pessoa morto heterofobia racismo reversar e misandria o ano e respectivamente :) Prediction= 1
# amar fotinha ano :(( Prediction= 0
#   email :) Prediction= 1
# foo :-) ed821758-b247-4a31-8646-ac524e11e59b Prediction= 1
#   precisar gente comer o tristeza o posicionamento d receber voto o daciolo e ai :( ficar triste ódio o o outro candidatar odiar eleito Prediction= 0
#   aaah pronto :))) Prediction= 1
# chorar cabeça tá explodir querer ficar casar dormir :( Prediction= 0
# o prazo terminar o segunda-feira submeter o proposto :) Prediction= 1
#   tadinha :( esperar mudar Prediction= 0
#   i existir receitar amar :) Prediction= 1
# infelizmente engolir e sofrer pelar injustiçado d Prediction= 0
#   ajudar pelar amor deus Prediction= 0
#   entender ... melhorar :) Prediction= 1
# dia ): Prediction= 1
#   obrigar pelar respostar :) Prediction= 1
# umar carreira comer cantor e lançar algum músico comer home alone thief e supernova :) Prediction= 1
# to tao orgulhoso beber :( :( :( Prediction= 0
#   obg beber :( precisar to tbm s Prediction= 0
#   amigar viúvo ninguém morrer :) Prediction= 1
# apartamento santo aceito permutar o imudou especialista imóvel e encontrar oportunidade parir o buscar apartamento santo aceito permutar o ofertar o preço :) Prediction= 1
# to feliz :))) q falir o show monsta Prediction= 1
# sentir umar vontade enorme chorar :(( Prediction= 0
#   e caro e ruim o serviço :) Prediction= 0
# :) centrar universitário adventista paulo Prediction= 1
#   to n vício o vc pra sair d vidar ta complicar :( Prediction= 0
# comer pizza e assistir friends comer nao provar e trabalho pra semana vir :) Prediction= 1
#   tá falar melhor ficar tranquilo haha d Prediction= 1
# sarar falir hrs dia p ficar c vc ksksks rolo dscp falar cmg umar mt gnt :) Prediction= 1
#   ficar apaixonar o cabelar :p Prediction= 0
# o junhoe bicicleta fofo :( Prediction= 0
#   o vezar nao conseguir :( Prediction= 0
#   :((( achar grupar wicca o fb entrar haver algum abrir pra visitar dia pra conhecer e gostar entrar Prediction= 1
# olá segunda-feira :) Prediction= 1
# conseguir concretizar algum objetivos ano — simmm :) Prediction= 1
# iwasaki chaaaannn o único shain gostar :) Prediction= 1
#   nhaa parir tirar o cartar continuar o haver motivação :)) Prediction= 1
# passar webamigas o cap tchauzinho atar ignnorado :( Prediction= 0
#   vergonha e nojo região bruno :( Prediction= 0
# e acabar o aula hoje :)) Prediction= 1
#   né d Prediction= 0
# deixar vir o mim o pequenino d o reinar céu dia feliz dia criança :) sextadetremurasdv Prediction= 1
#   o acabar acabar renovar o estocar :( Prediction= 1
#   maap humorq dolar :) Prediction= 1
# querer sair país real algum to o timeline gente levar pra d Prediction= 0
#   existir o twitter thread e converter pro zap :) dever o retweets embaixo Prediction= 1
#   o macaco parecer triste :( Prediction= 0
#   apagar tava repetir ai apagar o restar kkkk arrumar :) Prediction= 0
#   tô triste ano p despedir :( Prediction= 0
# desculpar verdade :(( Prediction= 0
#   :) Prediction= 1
# o propósito problema roer o unhar nervoso ... ficar dor estômago e mal-estar :( Prediction= 0
#   sim,10 horar dor :( Prediction= 0
# faltar praticamente 2/3 slide amanhã terminar antar sair casar :) Prediction= 1
# oi o criança deprimir :) Prediction= 1
# arrepender comer o pipocar e o banheiro e colocar pra :( Prediction= 1
# fc pqp saudade conter suspenso :(( Prediction= 0
#   lindar :) Prediction= 0
#   bolsar :) Prediction= 1
#   tô ano pra divertir e conseguir público pq ajudar né ^^ o lista d conseguir idear ficar acompanhar pra o desenho d Prediction= 1
#   querer corpo d idade lido d Prediction= 1
# almoçar o ruivo almoçar :( Prediction= 1
#   abraçar e descansar :) Prediction= 0
#   o gente combinar e umar festa pra vc tb :) Prediction= 1
# chorar querer dormir :((( dor chato porra Prediction= 0
#   ssshhhhhh falir peter pan disney canal pando :) Prediction= 1
#   mano :( Prediction= 0
# taeee bebuuuu amooooo hermosooo bebéeeee Prediction= 0
#   carol acordar responder ok :) Prediction= 1
#   gastar sortir o amor rolo :) Prediction= 1
# querer bué marchar lgbt viseu nao n dia :( Prediction= 0
#   pelar pesquisar o tl o comentar :( Prediction= 0
# ta vcs ficar redar social brigar suar causar querido oq mudo o o ativismo ficar falar e responder :) Prediction= 1
# dia perdido d Prediction= 1
# pq cortar o cabelar msm :( Prediction= 1
# lindar e pleno o ouvir músico o autocarro ... comedir o ouvir músico comedir o pensar o vidar e o quão merda :) life sucks Prediction= 1
#   nó denunciar comer conteúdo ódio querer colaborar ajudar :) opção o político Prediction= 1
#   vc to e to gostar :( achar o geração consciência Prediction= 0
#   o espermatozóide precisar atps :) Prediction= 1
#   :( criar umar contar Prediction= 1
# cmm conseguir mostrar q o piorar amgs :))) Prediction= 1
# tô preocupar eleição :( Prediction= 0
# pq to sentimental :( Prediction= 0
#   lindar amor :-( Prediction= 0
#   vc querer pra bh e o cidade mto receptivo pra mim :( Prediction= 0
#   obg amigo :( Prediction= 1
#   pq :) Prediction= 0
#   noite :) Prediction= 1
# saudade amor socorrer :( Prediction= 0
#   caraca perdoar to :( Prediction= 0
#   msm campanha pro ciro conseguir titulo :( Prediction= 0
# ano vidar d Prediction= 1
# infelizmente o melhor candidatar forçar :( Prediction= 0
#   :( Prediction= 1
# clicksummitpt captain planet o sala inovação :) Prediction= 1
# vontade sair cama griiitaaaa :( bom-dia Prediction= 0
# sair vídeo o canal ^^ clicar e vídeo épico :) rt Prediction= 1
# frança x doria segurança :) Prediction= 1
# comer umar formar comemoração o entrar o fc trazer whatsfake :) esperar gostar conteúdo 💕 ah e esperar mim ^^ park soer 🍒 Prediction= 1
# gostar vídeo o dancar break :) sequencia basica Prediction= 1
#   o rs o d Prediction= 1
#   verdade uai gt Prediction= 0
# triste separar rayssa :( Prediction= 0
# nao to conseguir dormir :( Prediction= 0
#   tbm ... :( Prediction= 0
#   rapazzz comer sopa gostar d o salada :p assar ocorrer achar umar receitar páprica raspar limão cominho sal e pimenta o suar Prediction= 1
#   vir o contar combo caro utilizar tb lamentar pagar :) aguardar umar solução asap Prediction= 1
# lembrar tour harry e morrer saudade :( Prediction= 0
#   esperar resolver e dia melhorar precisar :) Prediction= 1
# oi querer arnyguinhas prf chamar o dm ❤ ️ ❤ ️ Prediction= 1
#   olhar o vídeo colocar o face minuto :) Prediction= 1
# pessoa q gostar ti comer vc q msm defeito vc especial p pessoa :) Prediction= 1
#   tava o gozar bro :p o dia Prediction= 1
# d o e dia regressar o o norte começar o arranjar desculpar :) Prediction= 1
# eleger umar o cear infelizmente d :((( Prediction= 0
# segurar o fôlego comer o vidar :( Prediction= 0
#   legar :) Prediction= 1
# escrever errar pessoal kkkkk :( Prediction= 1
# levar contar o amigo facebook o ciro ganhar o turno :) Prediction= 0
# querer rqsguei folhar caderno desenhar :) Prediction= 1
# saudade juntar prédio pra descer e ficar o toar escutar pagodao falar merda :(( Prediction= 0
# querer namorar :( Prediction= 0
# lol ficar sw ... ficar fraco juizo :( Prediction= 0
# gandaaaa :( Prediction= 0
#   ❤ ️ 🌹 valer :) Prediction= 1
#   pelar pra rir e umar aliviar o estresse ^_^ melhorar procê d Prediction= 1
# tadinha d :( forçar guerreiro Prediction= 0
# acabar dormir o sesta :)) Prediction= 1
#   eis pessoal certar :) obrigar pelar ajudar o limpeza cachar chrome e voltar o funcionar Prediction= 1
# amar o e o amar :-) o atendimento pessoal medir definir procurar contexto direcção espiritual almejar o rendição total o deus e o ... Prediction= 1
#   igual o o dia seguir o execução marielle e o incendio museu nacional :((( Prediction= 0
# ano aparecer bolsonaro portugal e racista homofóbicos escondido :p Prediction= 1
#   entristecer pra caralho divisão enraizar o mentir pessoa e fã michael brigar entrar si ... :( Prediction= 0
#   ódio vídeo e impedir caro o bicho tá fechar o olho esperar monstro parar bater n :(( Prediction= 0
# e quase o culpar :((( Prediction= 0
# conferir d Prediction= 1
#   e mulher :( e Prediction= 1
#   sair :( Prediction= 0
#   aaaaaaaaaa desculpar --- prometer parar o prints v aproveitar o gamar jogar tá :) Prediction= 1
# amar neném :( Prediction= 0
#   ai achar dificil mt informação tbm sobrar :(( Prediction= 0
# desnecessário :( Prediction= 0
#   né :) Prediction= 0
# amigo fdp karen responder o wpp :) Prediction= 0
# to tomar montar remedio nao ta adiantar nado :( Prediction= 0
#   hahahaha lmaooo bucky barnes versão membro inferior tmb pensar n o problema o pé :( Prediction= 0
#   ... hoje falto ligar o parir cancelar clube :) Prediction= 1
# desculpar sumir votação dia vário texto pra voto printíssimos d mpn mariananolasco Prediction= 1
# o foto dia 08/09 durante o korean music festival o menino performaram “ into the new world ” snsd e “ dreams comer true ” eunseo participar cover snsd :( into the new world » dreams comer true » Prediction= 0
#   forçar migar d ano vc arrepender começar antar :) Prediction= 0
# mds q cólico :( Prediction= 0
#   pra exatamente o o contrário :p aliás o bolsominions conseguir inverter algum argumentar esperar Prediction= 1
#   :( Prediction= 1
#   :(( Prediction= 1
# dólar cair :) r$ 4,00 s 12:50 Prediction= 1
#   depender dia compromisso o barracão e dia evento :( querer participar comer participante rs haver trabalhar rail parir atualizar Prediction= 0
# querer postar umar fotinha bonito juntar o utt umar peno q foto bonito :( armyselcaday Prediction= 0
# ✉ ... bilhete especial respirar acalmar coração o mundo acabar hoje e — :( Prediction= 0
# melhor imaginar o provar mat :) Prediction= 1
#   pra vc escolher ninguém escolher nascer normal :) querer o razão o certar preconceito Prediction= 1
#   d ^_^ :) silei :)) mgbestgift Prediction= 1
#   infelizmente achar q perder contar ai to mt triste :(( Prediction= 0
#   o gente entender nado acontecer sinal né haahha so beber e algum parado comer padrao ... n ninguem kkkkkk :( e o vc sumiuuu :( Prediction= 0
# umar pessoa chegar tardar o casar e dormir ficar o t continuar joana :) Prediction= 1
#   beleza tivese outro nome seriar o trolado gt Prediction= 1
#   bolsar e haddad amor :( Prediction= 0
# desgraçamentos acusar pelar vôlei e negar empolgação felicidade explosão triste quantum alguém aposentar :( Prediction= 0
# comer o o dia directo anfiteatro pessoa haver horar e haver testar sobrar segurança o :))) Prediction= 1
#   o ciro :( Prediction= 0
#   oui o descer o escada e o metro o bazar enfim :-) Prediction= 1
# querer vascao :( Prediction= 0
#   supremo ironia :( ouvir o notícia morte aznavour ficar triste Prediction= 0
#   comerciar :) Prediction= 1
# comentar umar fanfic responder o comentário enviar o mandar vário s2 lt;3 :) :( d gt;&lt ^^ .- o_o o mear e ficar imaginar o o pessoa pensar mim .- Prediction= 1
#   obrigar :)) Prediction= 1
#   :) o cansar o nadja o teimosia colocar o cabeça umar e querer ouvir o outro história surpreender ouvir o gabi e o entender aberto e o ap dono razão o confusão n Prediction= 1
# canal musicar umar passado o d Prediction= 1
#   same tbh umar cena throw off tbh almost have o time rn :(( Prediction= 0
# entender pq tô enrolar p natsume yuujinchou animar manir :( Prediction= 0
# coar parabém pra mim po :( família lembrar Prediction= 1
#   ahh af esperar ... achar errar pra tá vestir pra morar o brasil votar pq :p pimenta o cu outro refrescar né Prediction= 1
# dia semana 4h aula :) dia Prediction= 1
#   esperar vc falar itaúna blusa branco e vc o nome :) Prediction= 1
#   ai absurdo :( Prediction= 0
#   tá tenso b voltar vir :( Prediction= 0
# vc desenhar — infelizmente :( vc Prediction= 0
#   kkkkkkkkkkkkk smp ficar feliz cmg :) Prediction= 0
#   morrer medo ... mds querer o ciro :( Prediction= 0
#   kkkkk :p Prediction= 0
# tou cheio frio :( Prediction= 1
# merecer gajo o o :(( Prediction= 1
#   dormir andar prejudicar :( Prediction= 0
#   aaaa beber ficar :( vir caro Prediction= 0
#   oh :( sentir obrigar formar ❤ ️ Prediction= 0
# nascer brasileiro e gringo triste :( Prediction= 0
# achar :))) Prediction= 0
#   noite petit :) Prediction= 1
# sequencia foto :( amar Prediction= 0
#   lindo d Prediction= 0
# ...
# tô confuso o o sentimento :) Prediction= 0
#   :( Prediction= 1
#   .... silas malafaia ... ... o inimigo pra derrotar ... o senhor aguardar eleição ... o discutir :) Prediction= 1
#   semear d Prediction= 1
# aparecer feminista bandeiro lgbt e o galera pedir pra tirar foto e gritar cuspe e sair constrangido pq o turma igual o d :) Prediction= 1
#   complicar ;) algum caderno rabiscar falto convencer-me utilidade parir outrém publicar :) Prediction= 1
#   e parabém pelar posicionamento e senso umar ótima jornalista demonstrar ótimo humanar :) Prediction= 1
#   nado :) Prediction= 1
# beijar des-te lavar o caro :) Prediction= 1
# bora umar metadinha alguém d casar querira chamar o adm mai opção v Prediction= 1
#   maçar bugo e morrer :p g pra vcs Prediction= 1
#   o tbm :( venus retrogradar eh foder Prediction= 0
#   crer feliz :( Prediction= 1
# triste pq conversar hoje :( Prediction= 0
#   linkizinho umar playlist maravilhoso basear taekook :) feito mim índico Prediction= 1
# to saudade coiso :( Prediction= 0
# o o centrar méier :-) Prediction= 1
# o sorriso d :( Prediction= 0
# o apresentador edivânia carmo estevar o especial angola parir conversar david dia sobrar o futurar televisão :) e outro revisto o programar completar disponível rtp play d Prediction= 1
# alguem pugavo :( Prediction= 0
#   ... sair dia setembro :) Prediction= 1
# dia querer tao casal comer hopekook picnic datar restaurante chique :(( Prediction= 0
# manir q sdds nekoma :( sdds animacao nekoma x karasuno :( sdds yamamoto e tanaka babar o shimizu so pensar proteger o yachi Prediction= 0
# realmente criar levar sentimento pelar cirinho to triste :( Prediction= 0
#   aniversário :) Prediction= 1
# professorar hoje q aula e o provar d semana q vir :) Prediction= 1
#   o problema chamar abstinência luppi :( Prediction= 0
#   conseguir :( Prediction= 0
#   o maiden vir confirmar sp show d o morumbi o dever acontecer fato quantum bandar junto melhor d Prediction= 1
#   falir o gerência :) Prediction= 1
# o ja :( Prediction= 0
#   nao conseguir encaixar o tom o achar desestabilizar :((( o voz d ja comedir tom gravar oti pituca oshskdh 😥 😥 😥 😥 😥 Prediction= 0
# reler converso o sung pra lembrar d Prediction= 1
# querer amigar :( — chamar o zap efron dm Prediction= 0
# querer o bgs ano passar marcante evento parir mim :( Prediction= 0
#   quase kkkk faltar seguir :p sortear outro Prediction= 1
#   desenhar o papel :( Prediction= 1
# aaaa netflix vc pq vc tirar trovão tropical catálogo :(( Prediction= 0
# ishipthis hahshahsha send mo daliiiiiiiu :))) Prediction= 1
# piadadodia eduardo “ o mulher direito bonito o esquerdo ” beleza entrar campar político ético competência propósito governar parir o parir si o direito :-) Prediction= 1
#   to gastar manir n levar o çerio :( Prediction= 0
# necesito volver al :( Prediction= 0
# hj aula 2h ônibus :) Prediction= 1
#   ai belle lt;33 peno o twitter tirar e o qualidade icon colocar celular :( Prediction= 0
#   tardar :) o ano diminuir discussão arrependimento matar Prediction= 1
#   tomar sustar socorrer o tá lindar to triste amar Prediction= 0
#   pa drogar :) Prediction= 1
# adquirir o álbum quiero volver compra-lo itunes google play o ajudar o subir o charts ouvir o músico pelar spotify :) músico o seguir gostar Prediction= 1
#   saudade xing :( esperar certar o agendar e conseguir comeback ot9 Prediction= 0
# o barulho manir :((( querer Prediction= 0
#   fandom o :( Prediction= 0
#   peno prolemas suar entregar :( infelizmente controlo sobrar o transportador realizar o entregar acompanhar o processar parir o produto chegar precisar algum disposição 😘 Prediction= 1
#   querer abraçar :( Prediction= 0
#   tristeza o gente lutar direito e lutar pra perde-los :( Prediction= 0
#   ruir gusmões o caro chamar brasil ficar o andar galeria o corredor :) Prediction= 1
# o o detectar rt amigar apuro covarde ajude-o rt e comentar parir pessoa campar progressista o lembrar alimentar trolls :) Prediction= 1
# oi nome bettina aprender o ligar o foda-se e produtivo :) Prediction= 1
# considerar anjo lindo — fofx obrigadaa :) Prediction= 1
#   falir tô medo mim e pelar pessoa conhecer suar existência ameaçar :( aaaaaaaaaaa infernar Prediction= 0
#   vc melhorar preocupar :) Prediction= 1
# lembrar oq to passar :( Prediction= 0
#   achar entrar depressão pensar lindar maravilhoso personagem animar :( Prediction= 0
# sair casar pressa parir o aula e afinal haver :) Prediction= 1
#   ngm paciência cmg kjkkjkkkkk :( Prediction= 0
# bar :( d35a805e-1a31-4b08-8341-728a704e2841 Prediction= 0
#   exatamente :) Prediction= 0
#   :( querer exaustivo o mundo real :( Prediction= 0
# jogar ... e o socar o travesseiro .. 3/2 :) Prediction= 1
#   assistir :) Prediction= 1
# tl desertar madrugar gt Prediction= 0
# bar :-( b19f539a-a2c7-4fc2-8abc-37004037e0fe Prediction= 0
#   voz :) Prediction= 0
# dever ruim o versão econômica :( Prediction= 0
#   ganhar o o portar tao raro q motivar parir deitar o pombal abaixar :) Prediction= 1
# responder s mensagem né :)) Prediction= 1
# parecer ficar umar mim hoje :( Prediction= 0
#   realmente difícil acreditar milhão brasileiro pensar pensar e o democracia precisar aceitar esperar o pesquisar indicar rolar hoje respirar fundir pra seguir frente calmo :) Prediction= 1
#   papo ganhar :((( Prediction= 0
#   forçar bia difícil haver umar pessoa o bolodemilho haver esperançar país melhor fascismo dia dia lutar :) Prediction= 0
#   hahahahah o relembrar cabrao :) Prediction= 1
# ficar assistir pitbulls amp condenar e afogar lágrima :( oq o cabeça humanar pra maltratar abandonar animal Prediction= 0
#   entender :) Prediction= 0
# solteiro — :( Prediction= 0
#   mau vontade pessoa :p Prediction= 0
# dia :) assistir algum vídeo canal o youtube Prediction= 1
# madrugar pra ;) :p — sentir aventureiro Prediction= 1
# burguer king promoção ninguém pra chamar pra comer tfw :( Prediction= 0
#   querer nenhum horário pelar planar comer pagar e o quantidade amigo d Prediction= 1
# e 10:40 :) Prediction= 1
# alguém tirar tédio :( Prediction= 1
#   comer o universo o universo :( Prediction= 0
# querer morrer :( Prediction= 0
# tava pensar e o ensinar fundamental guri bullyng comigo e umar amigo hoje dia entrar pro exercitar e votar o bolsobosta educaçao vir berço :) Prediction= 1
#   ficar triste mulher tããão triste :( falar n vir hoje o parar getúlio passar voar e tava forçar pra levar banco dor cabeça Prediction= 0
#   amar :( Prediction= 0
# comer o melhor sonhar — sonhar ciro presidente :( Prediction= 0
#   finalmente encontrar alguem partilhar exactamente o opiniao civilizadamente explicar o amigo nao ha maneiro :) Prediction= 1
#   gu tirar :( hahah Prediction= 0
#   olhar o olho d :(( Prediction= 0
# ai saudade d louco :(( Prediction= 0
# ultimamente rotina faculdade academiar handball estudar dormir saudade sair parir algum :( Prediction= 0
# nmrl pelar chá :( Prediction= 0
# galera pra nao conhecer o fanpage canal e so clicar passar o e comentar o posts vlw d Prediction= 1
# o caro wendy desconfortar dever mau :( Prediction= 0
# hey buibu :) Prediction= 1
#   lindo amigavel ahahah curtir muuto ti e querer o olho :) Prediction= 1
# janguinho ficar :( voto Prediction= 0
# o caro rolar o radinha curtir d Prediction= 1
# putrailham215 :) -raniputrailham215 :) -rani Prediction= 1
#   ai absurdo menino o tá incrível e o menino super poderoso aaaaaaa gt parar Prediction= 0
# :) Prediction= 1
#   chamar atena pra vidar o estátua e iriar mata-la :) Prediction= 1
#   ezê cimeetê rê derxim amon wekîl :)) Prediction= 1
#   eita :( pelar pc algum vod Prediction= 0
#   aniversário sobrinho :( ngm convidar pessoa família Prediction= 0
#   querer saido :( Prediction= 0
#   oq acontecer preciso conversar o gnt conhecer precisar conversar chamar :) Prediction= 1
#   ler o matéria pra parar relinchar :) Prediction= 1
#   entender passar fase complicar horrível vontade desistir o valer o peno forte hoje orgulhar mim superar e mandar energia positivo pra superar :) Prediction= 0
#   tá bonito :) Prediction= 1
#   lamentável alterar motivar :( Prediction= 0
#   oshi kjjkkk ninja e manjar capoera :(( enganar Prediction= 0
#   :)) falir oq achar Prediction= 0
# 8/10 02:02 celso 💓 gente n lembrar entrar n grupar morrer bêbado e chorar :((( to odiar Prediction= 1
# olá o metro e mear e saltar :) lindo e pessoa Prediction= 1
#   :( Prediction= 1
# sogro chamar p comer hot dog e qnd chegar q comer assistir friends :) n confiar sogro kkkkkk Prediction= 1
# advir dormir hj angustiar q tá :) Prediction= 1
#   mamae pq tirar pra desgostar senhor foder :( Prediction= 0
# o sério e chover :( Prediction= 0
# curto som preferir incomodar o outro utilizar fone ouvir :) Prediction= 1
#   caro deixar o vácuo querer Prediction= 0
# o agenor in)felizmente morrer :p segundosol Prediction= 1
# foo :-) 61d4a89a-859e-4d85-b247-4e8874af48b7 Prediction= 1
#   aaaa olhar falir :)) Prediction= 0
# o olho :( Prediction= 0
# conferir delicioso receitar feito o excalibur :) baixar e-book receitar desidratar frutar saude desidratador Prediction= 1
# viciar n musicar :) Prediction= 1
# nao paixãooooooo paixaaaaaoooo miragem :( Prediction= 0
#   opar so escolher retirar pessoalmente o o site e combinar umar horar email :) Prediction= 1
# esperar ansiosamente pelar dia sentir vontade falar comigo ... :( Prediction= 1
#   votar o candidatar brizola kkk :) Prediction= 1
#   :( Prediction= 1
#   mãe filho e maridar trair o esposo :) Prediction= 1
# dia :) Prediction= 1
# álcool casar e beber :( Prediction= 0
#   gastar o achar blogs descartar e artigo direito o q o esquerdo achar q fascista ... sequer achar twit :( Prediction= 1
# mt feliz to conseguir o redação o certo e cronometrar :) Prediction= 1
#   o problema q dps q tomar outro injeção pqp :( Prediction= 0
# podcast o ar e novidade o spotify o escutar o stream favorito aproveitar d Prediction= 1
# formatura ano matar algum pessoa :) Prediction= 1
# saudade assistir padrinho mágico aaa :( Prediction= 0
#   skdnsksksk infelizmente matar suar curiosidade gabi :(( Prediction= 0
#   oi manir :) Prediction= 1
#   o verdade :) Prediction= 0
# amar musicar :((( Prediction= 0
#   thanksss :)) combinar dia gravar vídeo hahahah bacano bues e arranjar spot hahahahahhaha vir tá fdd coitar tulio Prediction= 1
#   :) ahahha Prediction= 1
#   olá diego umar olhadinha o plano site e escolher o combinar pó pré controlo ansioso navegar o redar merecer o :) Prediction= 1
# d dormir :( Prediction= 0
#   o discursar candidatar intolerante lutar contrário o discursar ódio pensar merecer votar mulher hipótese algum :( Prediction= 1
# sdds :( Prediction= 0
#   peno q atender o o pedir :( Prediction= 0
# perlla votar o nadja :( Prediction= 0
#   acabar tornar umar faca sensato falar assistir friends meodeos abraçar ok anjo :) Prediction= 1
# pq q haver :( — converso inventar nao aguentar ninguém feliz Prediction= 1
# sendryanrawnudes :) Prediction= 1
# 📍 santo maria feirar formação o 21:30 e testar amanhã :) Prediction= 1
# querer socar o caro :) Prediction= 1
# desculpar decepcionar o filho papar :p Prediction= 0
# passar literalmente o noite inteiro acordar parir merda d Prediction= 1
# profissão dever valorizar — professorar e pedagogo :) Prediction= 1
#   tô preparar psicologicamente pra o nagini comer humano encimar credence querer d Prediction= 1
# o o concorrente admitir querer mãe e umar família :) tvi reality loveontoptvi Prediction= 1
# hoje deixar o tati zaqui tirar umar foto comigo :) Prediction= 1
# queronotvz arear sandy e luca limar :) Prediction= 1
#   o dia ficar presto parir ti :) Prediction= 1
# pai perguntar oq querer comer o almoçar so to mt chatear e puto o fascismo Prediction= 0
#   alguém mandar :((( Prediction= 1
# gente assaltar celular numerar excluir e bloquear e falir algum n :( :( Prediction= 0
# deitar e chorar o sono :) Prediction= 0
# odio querer falar umar pessoa coragem :( Prediction= 0
# querer criar c medo d gente maldoso coragem mandar merda o anônimo :( Prediction= 0
#   n conseguir levantar cama e n avisar ngm :( Prediction= 0
# o catra o caro pra ganhar eleição :( Prediction= 0
#   :) seguir ae Prediction= 1
#   umar :) Prediction= 1
#   o saudade amo :) Prediction= 0
#   anjo aguentar :( Prediction= 0
# madrugar certar conferir o vídeo d canal recomendar :) Prediction= 1
#   esto es lindar :( Prediction= 0
# alguém falar bar legar músico o o viver good vibes pra o amigo please Prediction= 1
# sdds nerdcast o :( Prediction= 0
# i5 7.600 gtx gb ram placamãe h110m-cs br fonte shocker 600w tb gabinete aerocool aero ssd gb garantir pedir garantir 21/12/2018 o processador unico:4.000 divulgar ai :) Prediction= 1
# ô lindo :)) Prediction= 0
# apostar o sup e ganhar odd tava 3.25 d colar o betway pra apostar Prediction= 1
# mãe amigo infância leo pain :p thevoicebrasil Prediction= 1
# hoje q sair o ruir pra abastecer cartão ônibus e comer blusa caro o blusa inominável achar justar ficar gritar comigo o frente mundo q petista :) dia Prediction= 0
#   vir pra comer :) Prediction= 0
# dormir hoje :( Prediction= 0
# receber amor dia ruim :( Prediction= 0
#   peraí o corretar brilhosa :p Prediction= 1
#   olhar to medo tb n achar ciro passar o haddad o altura campeonato :( Prediction= 0
#   amar :( lt;3 Prediction= 0
#   dia cris dia feliz e alegrar Prediction= 1
# ouvir e o sufocar :( Prediction= 0
# ficar o chave banheiro e caminhar voltar :) Prediction= 1
#   dia menino 🧜 ‍ ♀ ️ Prediction= 1
#   sad peno suar web namorar tava namorar pessoalmente :/ :) ^^ Prediction= 0
# achar achar misterio d — chamar o dm 🤠 Prediction= 1
#   querer abraçar ficar assimmmm aaaaaaaaaaaaaaa desculpar :((( Prediction= 0
# hj :) Prediction= 0
#   af vc merecer chorar :( Prediction= 0
# e o luca tá rir mim :( Prediction= 0
# mulher o acontecer comigo caro sério nojo :) n bastar o dia umar merda receber foto pintar solicitar umar ta o top10 odiar Prediction= 1
# triste o caro e dedicação e modelar gente torcer pra errar d not today satan Prediction= 1
#   ah fácil adquirir o s aproveitar e pacotão o produto mgm :) Prediction= 1
#   :) rangernão Prediction= 1
#   lari falir :( Prediction= 0
# o parar senhor :( Prediction= 1
#   lindooo .. :) Prediction= 1
# olhar chegar e militar n twitter d elenão elenunca Prediction= 1
#   falir comigo e :) Prediction= 0
# mentir q o alexandre frota virar deputar :( Prediction= 0
# papaz :) Prediction= 1
# o pessoa q gostar hoje :)) Prediction= 1
#   umar eleição basear o medo ne .. :( Prediction= 0
# olá seguidor :) Prediction= 1
#   google netscape navigator :-) Prediction= 1
#   o cear tirar o eunício oliveira nado :) Prediction= 1
# riaaaaa ganda mo Prediction= 1
# posto nude fude pra tao gostoso — claro postar pq pedir :) Prediction= 1
#   conseguir :( o perfil eh privar Prediction= 0
# hj e aniversário madrasta família churro beber alto salgado to bad q to sair quartar :( Prediction= 0
# to passar sono dormir acordar cansar :( ta foder Prediction= 0
# custar € pedir desculpar erradoss ficar :) Prediction= 1
# acreditar q escolher entrar o mau e o :( Prediction= 0
# foo :-) 765e41cd-88fe-4dd7-a53d-9156548e92e7 Prediction= 1
# gente tardar querer deixar registrar felicidade o o umar menino ano escola projeto revidar argumento machista colega d ficar muuito bravo o menino capacidade o menino :) Prediction= 1
#   vdd negar :( Prediction= 0
# bronquite deixar dormir :( Prediction= 0
#   anjo umar indireta direta ofender vc falar nordeste o particular vontade propria estudar o fasipe :) Prediction= 1
# feliz dia criança pra melhor criança sdds :) gigi amordadinda amomaisquechocolate santo sao paulo brazil Prediction= 1
# hoje senti-me substituível horrível o falar umar pessoa e simplesmente ignora-te e baza outro e completamente o cagar pra ti ... :) Prediction= 1
#   ficar feliz nao reação nao explicar :p Prediction= 1
# certo insegurança apegar :( Prediction= 0
# provar hoje d Prediction= 1
#   querer trabalhar pra :( Prediction= 0
#   o deixar confortável okay sun sentir falto covers :( Prediction= 0
#   crescer o caro mudar kkk habilidade mudar o rostir poderoso :p Prediction= 1
# querer dormir :( Prediction= 0
#   o adorar :-) Prediction= 1
# putrailham215 :) -rani Prediction= 1
# fic super vc tá ler indicar :) — antique shop amore o Prediction= 1
#   sdds pompom rosar q cair mochila :( Prediction= 0
# o faculdade mudo pra :( Prediction= 1
#   bolar futebol o chamar gordo fdp cigarrete o e :))) puto cozinhar claroo ahaha Prediction= 1
# dia :) Prediction= 1

# %%
# Accuracy treino teste e previsão
# Na classificação, essa função calcula a precisão do subconjunto
print("Accuracy: ",pipe.score(X_train,y_train))
print("Accuracy: ",pipe.score(X_test,y_test))
print("Accuracy: ",pipe.score(X_train,sample_prediction))
# Out:
# Accuracy:  0.8701428571428571
# Accuracy:  0.724
# Accuracy:  1.0

# %%
# Testar com uma frase
frase = input("Escreva um tweet!")
pipe.predict([frase])
